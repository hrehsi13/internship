# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException , NoSuchElementException
import re

# %%
driver =webdriver.Chrome("D:\web driver\chromedriver.exe")
driver.get('https://www.spinny.com/used-cars-in-delhi-ncr/s/?utm_medium=gads_c_display&utm_source=SPS_DisplayPerfMax_Top8_National_WC_PR&partner_id=EAIaIQobChMI2r2LoNDh-QIVA5hmAh1pKwYUEAAYBCAAEgI-fPD_BwE&source=googleads&sub_source=SPS_DisplayPerfMax_Top8_National_WC_PR&gclid=EAIaIQobChMI2r2LoNDh-QIVA5hmAh1pKwYUEAAYBCAAEgI-fPD_BwE')

# %%
car=[]
time.sleep(5)
start=0
end=10
for page in range(start,end):
    dr=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
    for i in dr[0:700]:
        car.append(i.text[5:])

car
# Out:
# ['Volkswagen Ameo Comfortline Plus 1.2L (P)',
#  'Kia Seltos HTK Plus G',
#  'Maruti Suzuki Ciaz Alpha Petrol',
#  'Tata Harrier XZ',
#  'Honda City V',
#  'Hyundai Creta 1.6 SX Plus',
#  'Hyundai New i20 Asta 1.2 IVT',
#  'Maruti Suzuki Vitara Brezza VDi AMT',
#  'Hyundai i10 Magna Petrol',
#  'MG Motors Astor Sharp 1.5 CVT',
#  'Maruti Suzuki Swift Dzire VXI',
#  'Hyundai Grand i10 Nios Magna 1.2 Kappa VTVT CNG',
#  'Hyundai Venue S 1.2',
#  'Honda City ZX CVT',
#  'Tata Nexon XZ+ Dark Edition',
#  'Maruti Suzuki XL6 Zeta MT Petrol',
#  'Hyundai Creta 1.6 SX Plus Auto Petrol',
#  'Renault Kwid 1.0 RXT Opt',
#  'Renault Kwid RXL',
#  'Hyundai Elite i20 Sportz Plus 1.2',
#  'Maruti Suzuki New Ertiga VDi',
#  'Maruti Suzuki Baleno Alpha Petrol',
#  'Maruti Suzuki Ciaz ZXI',
#  'Kia Sonet HTX 1.0 iMT',
#  'Maruti Suzuki Baleno Alpha Petrol',
#  'Honda Amaze 1.2 VX i-VTEC',
#  'Kia Sonet HTK Plus 1.5',
#  'Maruti Suzuki Ciaz Alpha Petrol AT',
#  'Hyundai Venue SX 1.5 CRDI',
# ...

# %%
len(car)
# Out:
# 7000

# %%
year=[]
time.sleep(5)
start=0
end=10
for page in range(start,end):
    dr=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
    for i in dr[0:700]:
        year.append(i.text[0:5])

year
# Out:
# ['2017 ',
#  '2019 ',
#  '2018 ',
#  '2019 ',
#  '2013 ',
#  '2015 ',
#  '2021 ',
#  '2020 ',
#  '2014 ',
#  '2022 ',
#  '2012 ',
#  '2021 ',
#  '2020 ',
#  '2020 ',
#  '2021 ',
#  '2020 ',
#  '2018 ',
#  '2020 ',
#  '2020 ',
#  '2019 ',
#  '2019 ',
#  '2018 ',
#  '2017 ',
#  '2020 ',
#  '2019 ',
#  '2022 ',
#  '2020 ',
#  '2017 ',
#  '2021 ',
#  '2019 ',
#  '2020 ',
#  '2021 ',
#  '2019 ',
#  '2020 ',
#  '2020 ',
#  '2016 ',
#  '2014 ',
#  '2019 ',
#  '2016 ',
#  '2017 ',
#  '2018 ',
#  '2013 ',
#  '2020 ',
#  '2017 ',
#  '2021 ',
#  '2021 ',
#  '2017 ',
#  '2021 ',
#  '2020 ',
#  '2018 ',
#  '2019 ',
#  '2019 ',
#  '2017 ',
#  '2016 ',
#  '2017 ',
#  '2021 ',
#  '2015 ',
#  '2016 ',
#  '2015 ',
#  '2014 ',
#  '2017 ',
#  '2020 ',
#  '2020 ',
#  '2015 ',
#  '2019 ',
#  '2020 ',
#  '2020 ',
#  '2022 ',
#  '2017 ',
#  '2017 ',
#  '2019 ',
#  '2016 ',
#  '2017 ',
#  '2018 ',
#  '2020 ',
#  '2020 ',
#  '2019 ',
#  '2016 ',
#  '2020 ',
#  '2015 ',
#  '2018 ',
#  '2022 ',
#  '2021 ',
# ...

# %%
len(year)
# Out:
# 7000

# %%
ki=[]
time.sleep(5)
start=0
end=10
for page in range(start,end):
    dr=driver.find_elements(By.XPATH,'//ul[@ class="styles__otherInfoSection"]/li[1]')
    for i in dr[0:700]:
        ki.append(i.text)

ki
# Out:
# ['17K km',
#  '20.2K km',
#  '57.1K km',
#  '37.2K km',
#  '44.8K km',
#  '86.2K km',
#  '13.1K km',
#  '56.5K km',
#  '30.7K km',
#  '5.3K km',
#  '53.7K km',
#  '3.5K km',
#  '33K km',
#  '23.2K km',
#  '22.9K km',
#  '44.8K km',
#  '48.1K km',
#  '37.7K km',
#  '13.7K km',
#  '34.6K km',
#  '28K km',
#  '40.1K km',
#  '33.6K km',
#  '29.8K km',
#  '60.8K km',
#  '8K km',
#  '50.5K km',
#  '83.3K km',
#  '14.1K km',
#  '18.2K km',
#  '14.4K km',
#  '14.3K km',
#  '28.1K km',
#  '21.4K km',
#  '18.9K km',
#  '72.1K km',
#  '62.6K km',
#  '63.4K km',
#  '81.3K km',
#  '18.3K km',
#  '38.2K km',
#  '55.3K km',
#  '15.4K km',
#  '97.7K km',
#  '21.8K km',
#  '5.1K km',
#  '43.1K km',
#  '24.2K km',
#  '39.8K km',
#  '25.6K km',
#  '18.2K km',
#  '53.7K km',
#  '40.5K km',
#  '81.3K km',
#  '14K km',
#  '40.7K km',
#  '58.1K km',
#  '65.4K km',
#  '55.2K km',
#  '70K km',
#  '70.2K km',
#  '47.3K km',
#  '25.2K km',
#  '76.5K km',
#  '9.3K km',
#  '30.3K km',
#  '11.4K km',
# ...

# %%
len(ki)
# Out:
# 7000

# %%
fuel=[]
time.sleep(5)
start=0
end=10
for page in range(start,end):
    dr=driver.find_elements(By.XPATH,'//ul[@ class="styles__otherInfoSection"]/li[2]')
    for i in dr[0:700]:
        fuel.append(i.text)

fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol+cng',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol+cng',
#  'Petrol',
# ...

# %%
len(fuel)
# Out:
# 7000

# %%
typee=[]
time.sleep(5)
start=0
end=10
for page in range(start,end):
    dr=driver.find_elements(By.XPATH,'//ul[@ class="styles__otherInfoSection"]/li[3]')
    for i in dr[0:700]:
        typee.append(i.text)

typee
# Out:
# ['Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Automatic',
#  'Automatic',
#  '',
#  'Automatic',
#  'Manual',
#  '',
#  'Manual',
#  'Automatic',
#  '',
#  'Manual',
#  'Automatic',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Automatic',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Automatic',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Automatic',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Automatic',
#  'Automatic',
#  '',
#  'Manual',
#  'Automatic',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Automatic',
#  'Manual',
#  '',
#  'Automatic',
#  'Manual',
#  '',
#  'Automatic',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Manual',
#  '',
#  'Manual',
#  'Automatic',
#  '',
#  'Manual',
#  'Manual',
# ...

# %%
len(typee)
# Out:
# 7000

# %%
price=[]
time.sleep(5)
start=0
end=10
for page in range(start,end):
    dr=driver.find_elements(By.XPATH,'//div[@ class="styles__priceSection "]/li[1]')
    for i in dr[0:700]:
        price.append(i.text)

price
# Out:
# ['₹8.02 Lakh',
#  '₹2.24 Lakh',
#  '₹7.85 Lakh',
#  '₹6.41 Lakh',
#  '₹5.27 Lakh',
#  '₹10.85 Lakh',
#  '₹7.83 Lakh',
#  '₹15.29 Lakh',
#  '₹4.95 Lakh',
#  '₹7.11 Lakh',
#  '₹9.44 Lakh',
#  '₹8.68 Lakh',
#  '₹3.19 Lakh',
#  '₹15.69 Lakh',
#  '₹3.56 Lakh',
#  '₹6.68 Lakh',
#  '₹7.78 Lakh',
#  '₹13.20 Lakh',
#  '₹9.92 Lakh',
#  '₹9.56 Lakh',
#  '₹10.91 Lakh',
#  '₹4.67 Lakh',
#  '₹3.84 Lakh',
#  '₹6.53 Lakh',
#  '₹9.60 Lakh',
#  '₹6.96 Lakh',
#  '₹7.68 Lakh',
#  '₹10.29 Lakh',
#  '₹6.37 Lakh',
#  '₹8.33 Lakh',
#  '₹8.82 Lakh',
#  '₹8.47 Lakh',
#  '₹10.26 Lakh',
#  '₹8.34 Lakh',
#  '₹5.06 Lakh',
#  '₹6.11 Lakh',
#  '₹7.41 Lakh',
#  '₹6.03 Lakh',
#  '₹17.71 Lakh',
#  '₹5.40 Lakh',
#  '₹3.23 Lakh',
#  '₹5.50 Lakh',
#  '₹5 Lakh',
#  '₹8.78 Lakh',
#  '₹5.96 Lakh',
#  '₹2.62 Lakh',
#  '₹8.71 Lakh',
#  '₹6.77 Lakh',
#  '₹9.95 Lakh',
#  '₹8.99 Lakh',
#  '₹8.20 Lakh',
#  '₹11.02 Lakh',
#  '₹7.60 Lakh',
#  '₹9.66 Lakh',
#  '₹8.86 Lakh',
#  '₹9.42 Lakh',
#  '₹9.10 Lakh',
#  '₹8.15 Lakh',
# ...

# %%
len(price)
# Out:
# 7000

# %%
locat=[]
time.sleep(5)
start=0
end=10
for page in range(start,end):
    dr=driver.find_elements(By.XPATH,'//div[@ class="TestDriveAvailability__testDriveItem"]')
    for i in dr[0:700]:
        locat.append(i.text)

locat
# Out:
# ['Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Grand Mall, Gurgaon',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, NSP, Delhi',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, NSP, Delhi',
# ...

# %%
len(locat)
# Out:
# 7000

# %%
# DataFrame
df = pd.DataFrame({})
df['Modle Name']=car
df['Manufacturing Year']=year
df['Kilometer']=ki
df['Fuel Type']=fuel
df['Car Type']=typee
df['Location']=locat
df['Price']=price

df
# Out:
#                                         Modle Name Manufacturing Year  \
# 0        Volkswagen Ameo Comfortline Plus 1.2L (P)              2017
# 1                            Kia Seltos HTK Plus G              2019
# 2                  Maruti Suzuki Ciaz Alpha Petrol              2018
# 3                                  Tata Harrier XZ              2019
# 4                                     Honda City V              2013
# ...                                            ...                ...
# 6995                       Maruti Suzuki Swift ZDi              2016
# 6996   Hyundai Grand i10 Nios Magna 1.2 Kappa VTVT              2021
# 6997                        Tata Tiago Revotorq XT              2019
# 6998               Maruti Suzuki Alto K10 VXI Plus              2022
# 6999  Mahindra Thar LX 4 STR Convertible Petrol AT              2021
#
#      Kilometer Fuel Type   Car Type                                Location  \
# ...

# %%
# saving the dataframe
df.to_csv('data.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor

# %%
data =pd.read_csv("data.csv")
data.head()
# Out:
#    Unnamed: 0                                 Modle Name  Manufacturing Year  \
# 0           0  Volkswagen Ameo Comfortline Plus 1.2L (P)                2017
# 1           1                      Kia Seltos HTK Plus G                2019
# 2           2            Maruti Suzuki Ciaz Alpha Petrol                2018
# 3           3                            Tata Harrier XZ                2019
# 4           4                               Honda City V                2013
#
#   Kilometer Fuel Type Car Type                           Location       Price
# 0    17K km    Petrol   Manual  Spinny Hub, Ghaziabad (Sahibabad)  ₹8.02 Lakh
# 1  20.2K km    Petrol   Manual  Spinny Hub, Ghaziabad (Sahibabad)  ₹2.24 Lakh
# 2  57.1K km    Petrol      NaN  Spinny Hub, Ghaziabad (Sahibabad)  ₹7.85 Lakh
# 3  37.2K km    Diesel   Manual  Spinny Hub, Ghaziabad (Sahibabad)  ₹6.41 Lakh
# 4  44.8K km    Petrol   Manual  Spinny Hub, Ghaziabad (Sahibabad)  ₹5.27 Lakh

# %%
data.shape
# Out:
# (7000, 8)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# Modle Name               0
# Manufacturing Year       0
# Kilometer                0
# Fuel Type                0
# Car Type              2260
# Location                 0
# Price                    0
# dtype: int64

# %%
data =data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#                                         Modle Name  Manufacturing Year  \
# 0        Volkswagen Ameo Comfortline Plus 1.2L (P)                2017
# 1                            Kia Seltos HTK Plus G                2019
# 2                  Maruti Suzuki Ciaz Alpha Petrol                2018
# 3                                  Tata Harrier XZ                2019
# 4                                     Honda City V                2013
# ...                                            ...                 ...
# 6995                       Maruti Suzuki Swift ZDi                2016
# 6996   Hyundai Grand i10 Nios Magna 1.2 Kappa VTVT                2021
# 6997                        Tata Tiago Revotorq XT                2019
# 6998               Maruti Suzuki Alto K10 VXI Plus                2022
# 6999  Mahindra Thar LX 4 STR Convertible Petrol AT                2021
#
#      Kilometer Fuel Type   Car Type                                Location  \
# ...

# %%
data =data.dropna(axis=0)

# %%
plt.figure(figsize=(3,3))
sns.countplot(data['Fuel Type'] ,palette="Set3")
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x ='Car Type', data=data ,palette ="Blues")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data['Manufacturing Year'] ,palette="Set2")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.stripplot(x = 'Manufacturing Year', y = 'Car Type', data = data)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x = 'Car Type', hue= 'Fuel Type', data = data)
plt.show()

# %%
data['Modle Name'].value_counts()
# Out:
# Maruti Suzuki Baleno Alpha Petrol               130
# Tata Harrier XZ                                  80
# Maruti Suzuki Baleno Delta Petrol                80
# Renault Kwid RXL                                 80
# Honda WR-V i-DTEC VX                             70
#                                                ...
# Ford EcoSport Titanium + 1.5L Ti-VCT             10
# Ford EcoSport SE 1.5L Ti-VCT                     10
# Maruti Suzuki S-Presso VXI+                      10
# Hyundai Verna 1.6 VTVT SX (O)                    10
# Mahindra Thar LX 4 STR Convertible Petrol AT     10
# Name: Modle Name, Length: 280, dtype: int64

# %%
data['Manufacturing Year'].value_counts()
# Out:
# 2017    710
# 2020    710
# 2019    640
# 2021    620
# 2018    440
# 2015    370
# 2014    350
# 2016    260
# 2022    220
# 2011    200
# 2013    120
# 2012    100
# Name: Manufacturing Year, dtype: int64

# %%
data['Kilometer'].value_counts()
# Out:
# 53.7K km    50
# 39.4K km    40
# 4.9K km     30
# 13.7K km    30
# 57.5K km    30
#             ..
# 91.9K km    10
# 3.3K km     10
# 69.9K km    10
# 55.7K km    10
# 1.3K km     10
# Name: Kilometer, Length: 376, dtype: int64

# %%
data['Fuel Type'].value_counts()
# Out:
# Petrol        3000
# Diesel        1600
# Petrol+cng     140
# Name: Fuel Type, dtype: int64

# %%
data['Car Type'].value_counts()
# Out:
# Manual       3850
# Automatic     890
# Name: Car Type, dtype: int64

# %%
data['Location'].value_counts()
# Out:
# Spinny Hub, Trillium Avenue, Gurgaon      1260
# Spinny Hub, Ghaziabad (Sahibabad)         1020
# Spinny Hub, Gaur City, Noida               880
# Spinny Hub, NSP, Delhi                     770
# Spinny Hub, Taj Vivanta, Dwarka, Delhi     550
# Spinny Hub, Grand Mall, Gurgaon            260
# Name: Location, dtype: int64

# %%
data['Price'].value_counts()
# Out:
# ₹4.26 Lakh     40
# ₹5.78 Lakh     40
# ₹8.67 Lakh     30
# ₹8.78 Lakh     30
# ₹4.64 Lakh     30
#                ..
# ₹4.62 Lakh     10
# ₹16.66 Lakh    10
# ₹9.95 Lakh     10
# ₹4.06 Lakh     10
# ₹8.68 Lakh     10
# Name: Price, Length: 369, dtype: int64

# %%
data.replace({"Manual":0, "Automatic":1},inplace =True)

# %%
data.replace({"Petrol":0, "Diesel":1, "Petrol+cng":2},inplace =True)

# %%
data.replace({"Spinny Hub, Taj Vivanta, Dwarka, Delhi":0, "Spinny Hub, NSP, Delhi":1, "Spinny Hub, Gaur City, Noida":2, "Spinny Hub, Ghaziabad (Sahibabad)":3, "Spinny Hub, Grand Mall, Gurgaon":4, "Spinny Hub, Trillium Avenue, Gurgaon":5},inplace =True)

# %%
data.head()
# Out:
#                                   Modle Name  Manufacturing Year Kilometer  \
# 0  Volkswagen Ameo Comfortline Plus 1.2L (P)                2017    17K km
# 1                      Kia Seltos HTK Plus G                2019  20.2K km
# 3                            Tata Harrier XZ                2019  37.2K km
# 4                               Honda City V                2013  44.8K km
# 6               Hyundai New i20 Asta 1.2 IVT                2021  13.1K km
#
#    Fuel Type  Car Type Location       Price
# 0          0         0        3  ₹8.02 Lakh
# 1          0         0        3  ₹2.24 Lakh
# 3          1         0        3  ₹6.41 Lakh
# 4          0         0        3  ₹5.27 Lakh
# 6          0         1        3  ₹7.83 Lakh

# %%
data.dtypes
# Out:
# Modle Name            object
# Manufacturing Year     int64
# Kilometer             object
# Fuel Type              int64
# Car Type               int64
# Location              object
# Price                 object
# dtype: object

# %%
le =LabelEncoder()

data["Modle Name"]=le.fit_transform(data["Modle Name"])

# %%
data["Kilometer"]=le.fit_transform(data["Kilometer"])

# %%
data["Price"]=le.fit_transform(data["Price"])

# %%
data.head()
# Out:
#    Modle Name  Manufacturing Year  Kilometer  Fuel Type  Car Type  Location  \
# 0         273                2017         44          0         0         3
# 1         104                2019         58          0         0         3
# 3         237                2019        146          1         0         3
# 4          19                2013        187          0         0         3
# 6          76                2021         16          0         1         3
#
#    Price
# 0    307
# 1     73
# 3    237
# 4    192
# 6    298

# %%
plt.figure(figsize = (15,15))
plotnumber = 1
for col in data.columns:
    if plotnumber <= 8:
        ax = plt.subplot(4,2, plotnumber)
        sns.distplot(data[col] ,color= 'b')
        plt.xlabel(col, fontsize =10)

    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,8))
graph=1

for column in data:
    if graph<=8: 
        ax=plt.subplot(4,2,graph)
        sns.boxplot(data[column], color='m')
        plt.xlabel(column,fontsize=10)
        

    graph+=1
plt.show()

# %%
x =data.drop(['Price'], axis=1)
y =data['Price']

# %%
x.skew().sort_values(ascending=False)
# Out:
# Car Type              1.599572
# Fuel Type             0.959895
# Kilometer             0.042754
# Location             -0.005878
# Modle Name           -0.069362
# Manufacturing Year   -0.576865
# dtype: float64

# %%
ss =StandardScaler()
ss.fit_transform(x)
# Out:
# array([[ 1.67162151, -0.23487746, -1.30538101, -0.72609065, -0.4808002 ,
#          0.15916068],
#        [-0.46514546,  0.46094701, -1.17457088, -0.72609065, -0.4808002 ,
#          0.15916068],
#        [ 1.21645221,  0.46094701, -0.35233578,  1.10458472, -0.4808002 ,
#          0.15916068],
#        ...,
#        [ 1.3808189 ,  0.46094701,  0.16156115,  1.10458472, -0.4808002 ,
#         -1.5953082 ],
#        [ 0.14174693,  1.50468371, -1.71649856, -0.72609065, -0.4808002 ,
#          0.15916068],
#        [-0.09848131,  1.15677148, -1.70715498, -0.72609065,  2.07986603,
#          0.15916068]])

# %%
x.shape
# Out:
# (4740, 6)

# %%
y.shape
# Out:
# (4740,)

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y ,test_size= 0.2)

# %%
# Linear regression

lr = LinearRegression()

lr.fit(x_train, y_train)
y_predict = lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# -0.00416779215109897

# %%
print(" MAE  :",metrics.mean_absolute_error(y_test,y_predict))
print(" MSE  :",metrics.mean_squared_error(y_test,y_predict))
print(" RMSE :",np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
# Out:
#  MAE  : 85.07746856618726
#  MSE  : 10367.076809368811
#  RMSE : 101.8188430958082

# %%
metrics.r2_score(y_test,y_predict)
# Out:
# -0.00416779215109897

# %%
cross_val_score(lr,x,y,cv=5).mean()
# Out:
# 0.006384377933787655

# %%
# DecisionTree

dt = DecisionTreeRegressor()

dt.fit(x_train, y_train)
y_predict = dt.predict(x_test)

# %%
dt.score(x_test,y_test)
# Out:
# 0.999003953921217

# %%
print(" MAE  :",metrics.mean_absolute_error(y_test,y_predict))
print(" MSE  :",metrics.mean_squared_error(y_test,y_predict))
print(" RMSE :",np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
# Out:
#  MAE  : 0.20991561181434598
#  MSE  : 10.283227848101266
#  RMSE : 3.2067472379502044

# %%
metrics.r2_score(y_test,y_predict)
# Out:
# 0.999003953921217

# %%
cross_val_score(dt,x,y,cv=5).mean()
# Out:
# 0.9981986466011229

# %%
# RandomForest

rf = RandomForestRegressor()

rf.fit(x_train, y_train)
y_predict = rf.predict(x_test)

# %%
rf.score(x_test,y_test)
# Out:
# 0.998909950006057

# %%
print(" MAE  :",metrics.mean_absolute_error(y_test,y_predict))
print(" MSE  :",metrics.mean_squared_error(y_test,y_predict))
print(" RMSE :",np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
# Out:
#  MAE  : 0.47271907304697436
#  MSE  : 11.253728810651655
#  RMSE : 3.3546577784703544

# %%
metrics.r2_score(y_test,y_predict)
# Out:
# 0.998909950006057

# %%
cross_val_score(rf,x,y,cv=5).mean()
# Out:
# 0.9981892608804799

# %%
# KNeighbors

knn = KNeighborsRegressor()

knn.fit(x_train, y_train)
y_predict = knn.predict(x_test)

# %%
knn.score(x_test,y_test)
# Out:
# 0.9960061826926836

# %%
print(" MAE  :",metrics.mean_absolute_error(y_test,y_predict))
print(" MSE  :",metrics.mean_squared_error(y_test,y_predict))
print(" RMSE :",np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
# Out:
#  MAE  : 0.9263713080168777
#  MSE  : 41.23236286919831
#  RMSE : 6.4212430937629446

# %%
metrics.r2_score(y_test,y_predict)
# Out:
# 0.9960061826926836

# %%
cross_val_score(knn,x,y,cv=5).mean()
# Out:
# 0.9981265924651679

# %% [markdown]
# ### using Regularization technique on linear regression

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV

# %%
lr.score(x_test,y_test)
# Out:
# -0.00416779215109897

# %%
lasscv =LassoCV(alphas =None, max_iter =100, normalize =True)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha =lasscv.alpha_
alpha
# Out:
# 0.007872077963302901

# %%
lasso_reg =Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.007872077963302901)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# -0.004164701990178266

# %%
print(" MAE  :",metrics.mean_absolute_error(y_test,y_predict))
print(" MSE  :",metrics.mean_squared_error(y_test,y_predict))
print(" RMSE :",np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
# Out:
#  MAE  : 0.9263713080168777
#  MSE  : 41.23236286919831
#  RMSE : 6.4212430937629446

# %%
metrics.r2_score(y_test,y_predict)
# Out:
# 0.9960061826926836
